# %% [markdown]
# #the program attempts predict the future price of bitcoin

# %%
#Import the libraries
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt

# %%
#collect and clean the data
df = pd.read_csv('BTC-USD.csv')
df = df.dropna()
#Look at the data
df
# Out:
#             Date          Open          High           Low         Close  \
# 0     2014-09-17    465.864014    468.174011    452.421997    457.334015
# 1     2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2     2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3     2014-09-20    394.673004    423.295990    389.882996    408.903992
# 4     2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...          ...           ...           ...           ...           ...
# 2708  2022-02-15  42586.464844  44667.218750  42491.035156  44575.203125
# 2709  2022-02-16  44578.277344  44578.277344  43456.691406  43961.859375
# 2710  2022-02-17  43937.070313  44132.972656  40249.371094  40538.011719
# 2711  2022-02-18  40552.132813  40929.152344  39637.617188  40030.976563
# 2712  2022-02-19  40022.132813  40246.027344  40010.867188  40126.429688
#
#          Adj Close       Volume
# 0       457.334015     21056800
# ...

# %%
#Show the data visually
df.plot(x='Date', y='Close',figsize=(16,6))
# Out:
# <Axes: xlabel='Date'>

# %%
#Create the model
model = RandomForestRegressor()

# %%
#train the model
X= df[['Open','High','Low','Volume']]
# X = X[:int(len(df)-1)] # This line is causing the error, remove it.
y = df['Close']
model.fit(X,y) #training the model

RandomForestRegressor()
# Out:
# RandomForestRegressor()

# %%
#Test the model
predictions  = model.predict(X)
print('The model score is',model.score(X,y))
# Out:
# The model score is 0.9998958606671332

# %%
#Test the model
new_data = df[['Open','High','Low','Volume']].tail(1)
predcition = model.predict(new_data)
print('The model predicts the last day or day to be',predcition)
print('Actual Value is :',df['Close'].tail(1).values[0])
# Out:
# The model predicts the last day or day to be [39939.05222692]
# Actual Value is : 40126.429688
